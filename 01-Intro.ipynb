# %% [markdown]
# <table align="center">
#    <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ds5110/summer-2021/blob/master/01-Intro.ipynb">
# <img src="https://github.com/ds5110/summer-2021/raw/master/colab.png"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # 01-Intro: Python basics
#
# This notebook introduces the basics of Python.
#
# ### References
#
# * [Whirlwind Tour of Python](https://jakevdp.github.io/WhirlwindTourOfPython/) -- HTML
# * [Whirlwind Tour of Python](https://github.com/jakevdp/WhirlwindTourOfPython) -- Jupyter notebooks
#
# ### Additional References
#
# * [The Python Tutorial](https://docs.python.org/3/tutorial/index.html) - python.org

# %% [markdown]
# # Alternatives to Python: R and Julia
#
# * R is a statistical programming environment and language with strong support from the statistics community.
# * Julia is a relatively new language that has been designed from the ground up to fix some problems with Python.
# * Check out a recent [Northeastern ranking](https://www.northeastern.edu/graduate/blog/most-popular-programming-languages/) of the 10 most popular languages.
#
# # Python 2 or 3?
#
# Python underwent a big (breaking) change from version 2 to version 3. It has recovered and is going strong.
# * We'll be using Python 3 for everything
# * We'll be using Colab notebooks for everything.
#
#
# # Python core packages
#
# Python has a collection of core packages that build on the basics.
#
# * NumPy -- efficient computation with multi-dimensional data arrays,
# * Pandas -- DataFrame objects to manipulate, filter, group, and transform data.
# * SciPy -- numerical integration and interpolation,
# * Matplotlib -- API for creation of publication-quality plots and figures,
# * Scikit-Learn -- toolkit for common machine learning algorithms,
# * Jupyter -- interactive notebook environment for exploratory analysis and executable documents.
#     * Colab is Jupyter as a service with some nice enhancements, including scalable access to GPUs.
#
# We'll be using all of these libraries extensively in this course, and others as well. But first things first...

# %% [markdown]
# # Basic syntax
#
# * End-of-line terminates a statement
# * Use `\` to continue a statement to the next line
# * Comment lines start with `#`
# * You can use triple quotes `"""` to begin and end multi-line strings (comments)
# * White space matters!!!  (at the beginning of a line)
# * Use indentation (at the beginning of the line) for blocks of code
# * Reference: [02-Basic-Python-Syntax.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/02-Basic-Python-Syntax.ipynb)

# %%
# This is a comment
x = 42  # This line assigns the value of 42 to the variable "x"
for i in [0, 1, 2]:
  # The code block in the for loop is indented
  x += 1
  print(x)

print("What is x now?  A:", x)
# Out:
# 43
# 44
# 45
# What is x now?  A: 45

# %%
# Another way to do the same thing
x = 42 
for i in range(3):
  x += 1
  print(x)

print("What is x now?  A:", x)
# Out:
# 43
# 44
# 45
# What is x now?  A: 45

# %%
# Parentheses are for grouping
x = 1 + 2 * 3
print(x)
# Out:
# 7

# %%
x = (1 + 2) * 3
print(x)
# Out:
# 9

# %%
# Parentheses are also for calling
print
# Out:
# <function print>

# %%
print("Hello, world!")
# Out:
# Hello, world!
# NoneType

# %% [markdown]
# # Variables and Objects
#
# * Python variables are pointers
# * Python is dynamically typed
# * Ref: [03-Semantics-Variables.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/03-Semantics-Variables.ipynb)

# %%
# This kind of thing doesn't work in C, where variables are statically typed
# In C, you would define the type of "x" with, for example, "int x = 4"
x = 4 # x is an int
x = "hello" # x is a string
x = [1,2,5] # x is a list with 3 elements

# %%
# It also leads to some interesting behavior
x = [5, 1, 4]
y = x

# %%
x.append(42)
x # x now has 4 elements
# Out:
# [5, 1, 4, 42]

# %%
# Can you predict what happens when you run this cell?
y
# Out:
# [5, 1, 4, 42]

# %%
x = "Hello, world!"
x # x is now a string
# Out:
# 'Hello, world!'

# %%
# Can you predict the result when you run this cell?
y
# Out:
# [5, 1, 4, 42]

# %% [markdown]
# ## In Python, everything is an object
#
# * Objects have "attributes" (metadata)
# * Objects have "methods" (functions)
# * Attributes and methods are accessed with dot "." notation
# * Attrbutes and methods are objects as well

# %%
x = [1, 2, 3]
print(x)
print(type(x))

x.append(100)
print(x)

print(type(x.append))
print(x.append)
# Out:
# [1, 2, 3]
# <class 'list'>
# [1, 2, 3, 100]
# <class 'builtin_function_or_method'>
# <built-in method append of list object at 0x7fb5bea41af0>

# %% [markdown]
# # Operators
#
# This is a good notebook to open directly in Colab
#
# * Go to your Google Drive
# * Create a new Colab notebook ("+" menu)
# * File > Open notebook
# * Github (provide URL)
#
# Vanderplas provides a nice overview of
#
# * Arithmentic operations
# * Bitwise operations
# * Comparison operations
# * Boolean operations
# * Identity and membership operations
#
# Ref: [04-Semantics-Operators.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/04-Semantics-Operators.ipynb)

# %% [markdown]
# # Built-in scalar types
#
# | Type        | Example        | Description                                                  |
# |-------------|----------------|--------------------------------------------------------------|
# | ``int``     | ``x = 1``      | integers (i.e., whole numbers)                               |
# | ``float``   | ``x = 1.0``    | floating-point numbers (i.e., real numbers)                  |
# | ``complex`` | ``x = 1 + 2j`` | Complex numbers (i.e., numbers with real and imaginary part) |
# | ``bool``    | ``x = True``   | Boolean: True/False values                                   |
# | ``str``     | ``x = 'abc'``  | String: characters or text                                   |
# | ``NoneType``| ``x = None``   | Special object indicating nulls                              |
#
# ### Reference
#
# * [05-Built-in-Scalar-Types.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/05-Built-in-Scalar-Types.ipynb)

# %%
# Q: What's the type of x?
x = 42
print(type(x))

x = 42.0
print(type(x))
type(x)
# Out:
# <class 'int'>
# <class 'float'>
# float

# %% [markdown]
# ## An aside on numerical precision
#
# Some of the following results may be surprising.
#
# They arise because computers store base-10 (decimal) values as base-2 (binary) with a finite number of bits.
#
# As a result, some decimal values are represented with binary approximations. These approximations introduce "roundoff" errors that can accumulate and cause problems in some calculations, depending on the algorithm.
#
# Format strings are introduced in:  [14-Strings-and-Regular-Expressions.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/14-Strings-and-Regular-Expressions.ipynb)

# %%
print(.3)
print("0.3 = {0:.17f}".format(0.3))
print("0.1 + 0.2 = {0:.17f}".format(.1 + .2))

# The "assert" statement throws an error if the test condition fails
# The next three statements run without an Error
# The test conditions are all True because of limited numerical precision
assert 0.3 == 3 / 10
assert 0.3 == 0.29999999999999999
assert 0.3 == 0.30000000000000000

# This statement throws an AssertionError if you use "==" instead of "!="
assert 0.1 + 0.2 != 0.3
# Out:
# 0.3
# 0.3 = 0.29999999999999999
# 0.1 + 0.2 = 0.30000000000000004

# %% [markdown]
# # Built-in data structures
#
# Python has several built-in compound types, which act as containers for other types:
#
# | Type Name | Example                   |Description                            |
# |-----------|---------------------------|---------------------------------------|
# | ``list``  | ``[1, 2, 3]``             | Ordered collection                    |
# | ``tuple`` | ``(1, 2, 3)``             | Immutable ordered collection          |
# | ``dict``  | ``{'a':1, 'b':2, 'c':3}`` | Unordered (key,value) mapping         |
# | ``set``   | ``{1, 2, 3}``             | Unordered collection of unique values |
#
# Round, square, and curly brackets have distinct meanings for these collections.
#
# * Reference: [06-Built-in-Data-Structures.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/06-Built-in-Data-Structures.ipynb)

# %% [markdown]
# ## Lists

# %%
# a list containing prime numbers
l = [2, 3, 5]

# %%
# length of a list
len(l)
# Out:
# 3

# %%
# append to a list
l.append(11)
l
# Out:
# [2, 3, 5, 11]

# %%
# adding lists concatenates them
l = l + [13, 17]
l
# Out:
# [2, 3, 5, 11, 13, 17]

# %% [markdown]
# ## Beware
#
# ..of running cells out of sequence in Jupyter/Colab. It can be very confusing.
#
# For example, try running the cell above a second time.

# %%
# sort() method sorts in-place
l = [2, 5, 1, 6, 3, 4]
l.sort()
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Try: 
a = ("b", "g", "a", "d", "f", "c", "h", "e")
x = sorted(a)
print(x)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
# How will I remember whether it's type(l) or l.type()?
# Try searching for: "type of object python"

# %%
# Python is dynamically typed; you can have lists of elements of different types
# Note: you can't (easily) sort lists with different types
l = [1, 'two', 3.14, [0, 3, 5]]
l
# Out:
# [1, 'two', 3.14, [0, 3, 5]]

# %% [markdown]
# ## Indexing and slicing lists
#
#
# <img src="https://github.com/jakevdp/WhirlwindTourOfPython/raw/master/fig/list-indexing.png" width=500>

# %%
# indexing starts at 0
l = [2, 3, 5, 7]
l[0]

# %%
# the last element in a list
l[-1]

# %%
# slicing -- start index (inclusive) : end index (exclusive)
l[0:3]

# %%
# you can use a step size
l[0:5:2]

# %%
# if you leave out values, you get sensible defaults
print(l[:])
print(l[:3])
print(l[3:])
print(l[::2])

# %%
# How will you remember slicing syntax?
# Try searching for: "slice list in python"

# %% [markdown]
# ## Tuples
#
# Tuples are immutable lists

# %%
# define tuples with parentheses, not square brackets
t = (2, 3, 5, 7)

# %%
# or no parantheses at all
t = 1, 2, 3
t

# %%
# they can be unpacked with similar syntax 
a, b, c = t
print(a, b, c)

# %%
# and accessed the same way as lists
t[:3]

# %%
# but since they're immutable, the next line will throw an error
#t.append(4)

# %%
# they're used when a function returns multiple values
x = 0.125
x.as_integer_ratio()
# Out:
# (1, 8)

# %%
# and they can be unpacked from return values as you might expect
numerator, denominator = x.as_integer_ratio()
denominator
# Out:
# 8

# %% [markdown]
# ## Dictionaries
#
# key-value pairs -- unordered -- mutable

# %%
# defined with curly braces -- {'key': value}
numbers = {'one':1, 'two':2, 'three':3}
numbers['two']  # accessed with keys using square brackets

# %%
# mutable
numbers['guess'] = 5
numbers

# %%
numbers[3] = 42
numbers

# %% [markdown]
# ## Set
#
# unordered collection of unique values
#
# they're mutable (you can add and remove values)
#
# they support mathematical operations of sets (union, intersection, etc.)

# %%
# defined with curly brackets
s = {1, 1, 9, 13, 3}
s
# Out:
# {1, 3, 9, 13}

# %%
# you can't access elements of a set directly
# s[0] throws an error
# but you can easily turn a set into a list
list(s)
# Out:
# [1, 3, 13, 9]

# %%
# What happens if you run this cell?
# What happens if you run this cell multiple times?
s.add('a')
s
# Out:
# {1, 13, 3, 9, 'a'}

# %%
# What happens if you run this cell?
s.add('hello')
s
# Out:
# {1, 13, 3, 9, 'a', 'hello'}

# %%
# What happens if you run this cell?
s.update('hello')
s
# Out:
# {1, 13, 3, 9, 'a', 'e', 'h', 'hello', 'l', 'o'}

# %%
# Can you predict what will happen with this cell?
# We'll cover iterators later -- see: 10-Iterators.ipynb
for i in "hello":
  print(i)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# ## Documentation
#
# * online -- https://docs.python.org/3/library/ -- standard library
#   * For example: [lists](https://docs.python.org/3/library/stdtypes.html#lists)
# * `help(list)` -- terminal, Jupyter, Colab
# * `list?` -- Jupyter, Colab
# * `list` -- Colab (on hover)
# * stackoverflow -- but be careful

# %%
# In Colab (as you type parentheses) online documentation is automatic.
list()

# %%
# With Colab and Jupyter, you can execute a statement with question mark
# Uncomment the next line and run this cell to see how that works.
#list?

# %%
# You can uncomment and run the next line, which also works in a terminal (command line)
# Note: the slash `/` indicates that previous list of arguments are "positional" only
# https://www.python.org/dev/peps/pep-0436/#functions-with-positional-only-parameters
# You can find this out with careful use of stackoverflow and google
# Try googling: "python help slash as argument"
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the list.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the list in memory, in bytes.
#  |
#  |  append(self, object, /)
#  |      Append object to the end of the list.
#  |
#  |  clear(self, /)
#  |      Remove all items from list.
#  |
#  |  copy(self, /)
#  |      Return a shallow copy of the list.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  extend(self, iterable, /)
#  |      Extend list by appending elements from the iterable.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  insert(self, index, object, /)
#  |      Insert object before index.
#  |
#  |  pop(self, index=-1, /)
#  |      Remove and return item at index (default last).
#  |
#  |      Raises IndexError if list is empty or index is out of range.
#  |
#  |  remove(self, value, /)
#  |      Remove first occurrence of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  reverse(self, /)
#  |      Reverse *IN PLACE*.
#  |
#  |  sort(self, /, *, key=None, reverse=False)
#  |      Stable sort *IN PLACE*.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %% [markdown]
# # Control flow
#
# Indentation is critically important in Python!
#
# * if-elif-else
# * for loops (with iterators)
# * Ref: [07-Control-Flow-Statements.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/07-Control-Flow-Statements.ipynb)

# %%
# if-elif-else -- note the indentation!
x = -15

if x == 0:
    print(x, "is zero")
elif x > 0:
    print(x, "is positive")
elif x < 0:
    print(x, "is negative")
else:
    print(x, "is unlike anything I've ever seen...")

# %%
for N in [2, 3, 5, 7]:
    print(N, end=' ') # print all on same line

# %%
# the range object generates a sequence in a for loop
for i in range(3, 10):
    print(i)

# %%
# note that range() itself is not a list
range(3,10)

# %%
# but you can turn it into a list
list(range(3,10))

# %%
# while continues until a condition is met
i = 5
while i < 10:
  print(i, end=" ")
  i += 1

# %% [markdown]
# ## Control flow with `continue` and `break`
#
# `continue` will skip to the next iteration (you could achieve the same thing with `if-else`)
#
# `break` will exit the loop entirely

# %%
for n in range(20):
    # if the remainder of n / 2 is 0, skip the rest of the loop
    if n % 2 == 0:
        continue
    print(n, end=' ')

# %%
# Fill a list with all Fibonacci numbers up to a certain value
a, b = 0, 1
amax = 100
l = []

while True:
    (a, b) = (b, a + b)
    if a > amax:
        break
    l.append(a)

print(l)

# %% [markdown]
# # Functions
#
# * Ref: [08-Defining-Functions.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/08-Defining-Functions.ipynb)
# * `*args` (arguments) and `**kwargs` (keyword arguments)

# %%
# print is a function
print()

# %%
# keyword arguments (kwargs) must come at the end
print(1, 2, 3, sep='--')

# %%
# Notice what happens when you leave out the keyword
print(1, 2, 3, '--')

# %% [markdown]
# ## Defining functions
#
# `def` and `lambda`
#
# Use functions to create clean, readable and reusable (DRY) code.

# %%
def fibonacci(N):
    L = []
    a, b = 0, 1
    while len(L) < N:
        a, b = b, a + b
        L.append(a)
    return L

# Note that a & b aren't accessible outside the function
fibonacci(5)

# %%
# You can "return" multiple values
def fibonacci(N):
    L = []
    a, b = 0, 1
    while len(L) < N:
        a, b = b, a + b
        L.append(a)
    return L, a, b

fibonacci(5)

# %%
# You can define user-modifiable default values with keyword arguments
def fibonacci(N, a=0, b=1):
    L = []
    while len(L) < N:
        a, b = b, a + b
        L.append(a)
    return L

print(fibonacci(5, 6, 5))
print(fibonacci(5, 0, 1))

# %% [markdown]
# ## flexible arguments
#
# `*args` -- arguments (expand as sequence)
#
# `**kwargs` -- keyword arguments (expand as a dictionary)

# %%
def catch_all(*args, **kwargs):
    print("args =", args)
    print("kwargs = ", kwargs)

catch_all()
catch_all(1, 2, 3, a=4, b=5)

# %%
# variable names "args" and "kwargs" are simply conventions
inputs = [1,4,5]
keywords = {'pi': 3.24, "42": 3}

catch_all(*inputs, **keywords)

# %% [markdown]
# ## lambda functions
#
# anonymous functions -- one-liners

# %%
# A concise way to define a function
add = lambda x, y: x + y
add(1, 2)

# %%
# We'll consider a common application of lamba functions
# Note that you can sort a list of scalars
data = [11, 7, 42, 3]
sorted(data)

# %%
# But you can's simply sort a list of dictionaries
data = [{'first':'Guido', 'last':'Van Rossum', 'YOB':1956},
        {'first':'Grace', 'last':'Hopper',     'YOB':1906},
        {'first':'Alan',  'last':'Turing',     'YOB':1912}]

# the next line throws a TypeError
# sorted(data)

# %%
# sort() has an optional key argument, which allows
# you to specify a function that customizes the sort order
# For example, you can sort alphabetically by first name as follows
# Q: How would you sort by year of birth (YOB)?
sorted(data, key=lambda item: item['first'])

# %% [markdown]
# # Errors and exceptions
#
# * [09-Errors-and-Exceptions.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/09-Errors-and-Exceptions.ipynb)
# * Catch exceptions with `try` and `except`

# %%
# This example throws a ZeroDivisionError
# Python provides helpful information, including the line where the error occurred
# Q: What happens if you uncomment the next line?  A: Try it
# 1/0

# %%
# You can define a custom function that knows what to do with 1/0
# So you can catch the error before it interrupts execution of your code
def safe_divide(a, b):
    try:
        return a / b
    except:
        return 1E100

safe_divide(1,0)

# %%
# But you may want to be more specific about the error you catch
print(safe_divide(1, 'hello'))

def safe_divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return 1E100
    except:
        return "that just doesn't make sense"

print(safe_divide(1, 'hello'))

# %%
# You can raise your own errors
#raise RuntimeError("Ouch, that hurt!")

# %%
# You can create a custom error with class inheritance
class MySpecialError(ValueError):
    pass

#raise MySpecialError("here's the message")

# %%
# Then you can fine tune the way you treat errors of various types.
# MySpecialError is a special type of ValueError; you can catch it specifically
# You can also catch it with the relatively generic ValueError exception
# But a generic ValueError won't be caught by the MySpecialError exception.
# NOTE: You can change the order of the exceptions to demonstrate...
try:
    print("do something then raise an error")
    raise MySpecialError("[informative error message here]")
    raise ValueError("Ouch!")
except MySpecialError:
    print("caught my special error")
except ValueError:
    print("caught value error")
#except ValueError:
#    print("caught value error")

# %%
# And you can also use...try-except-else-finally
try:
    print("try something here")
except:
    print("this happens only if it fails")
else:
    print("this happens only if it succeeds")
finally:
    print("this happens no matter what")

# %% [markdown]
# # Iterators
#
# Iterators are Python objects that have an `iterator` interface. A list is an iterator, and so is the `range()` object.
#
# Once you create a list, the entire list resides in memory. That means it's limited in size.
#
# Iterators are more general.
#
# Ref: [10-Iterators.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/10-Iterators.ipynb)

# %%
# As we've seen, you can iterate over a list
# The "for" statement creates an iterator from the list.
# In other words, you iterate over the list because lists have an "iterator" interface
for value in [2, 4, 6, 8, 10]:
    print(value + 1, end=' ')

# %%
# In the previous statement, Python is actually using the
# iterator, which you can get using the built-in "iter()" function
a = iter([2, 4, 6, 8, 10])
a

# %%
a = iter([2, 4, 6, 8, 10])
a
list(a)
# Out:
# [2, 4, 6, 8, 10]

# %%
# You can use the built-in `next()` function to access values from iterators
# Run this cell repeatedly to see how it works.
a = iter([2, 4, 6, 8, 10])
print(next(a))

# %%
# You cannot create a list of length `N=10**12` because it would overrun memory.
# But you can iterate over `N` values with an iterator.
N = 10 ** 12
for i in range(N):
    if i >= 10: break
    print(i, end=', ')

# %% [markdown]
# ## Some Python iterators
#
# * `enumerate`
# * `zip`
# * `map`
# * `filter`

# %%
# For example, if you need to keep track of the index of an iterator, you can do this...
L = [2, 4, 6, 8, 10]
for i in range(len(L)):
    print(i, L[i])

# %%
# Or you can do the same thing more succinctly with `enumerate`
for i, val in enumerate(L):
    print(i, val)

# %%
# `zip` lets you iterate over multiple lists
L = [2, 4, 6, 8, 10]
R = [3, 6, 9, 12, 15]
for lval, rval in zip(L, R):
    print(lval, rval)

# %%
# Q: And what if you want to keep track of the index using zip?
L = [2, 4, 6, 8, 10]
R = [3, 6, 9, 12, 15]
for i, (lval, rval) in enumerate(zip(L, R)):
    print(i, lval, rval)

# %%
# the `map` iterator applies a function to an iterator
# for example, to find the first 10 square numbers
square = lambda x: x ** 2
for val in map(square, range(10)):
    print(val, end=' ')

# %%
# the `filter` iterator is similar, 
# except it only passes values for which the function evalutes to true
is_even = lambda x: x % 2 == 0
for val in filter(is_even, range(10)):
    print(val, end=' ')

# %% [markdown]
# ## Iterators as function arguments

# %%
# you can also pass iterators as function arguments
# using "*args" notation to expand the iterator
print(*range(10))

# %%
# likewise, here's a more concise implementation of the map cell above
print(*map(lambda x: x ** 2, range(10)))

# %%
# You can do the same thing with the zip iterator
# Note that this prints a sequence of 4 2-element tuples
L1 = (1, 2, 3, 4)
L2 = ('a', 'b', 'c', 'd')
z = zip(L1, L2)
print(*z)
# Out:
# (1, 'a') (2, 'b') (3, 'c') (4, 'd')

# %%
# You can apply zip again to write a sequence of 2 4-element tuples 
# This effectively unzips the zip iterator
z = zip(L1, L2)
for a in zip(*z):
  print(a)

z = zip(L1, L2)
print('more succinctly:', *zip(*z))
# Out:
# (1, 2, 3, 4)
# ('a', 'b', 'c', 'd')
# more succinctly: (1, 2, 3, 4) ('a', 'b', 'c', 'd')

# %% [markdown]
# ## "itertools" has some other iterators
#
# * [itertools reference docs](https://docs.python.org/3/library/itertools.html)
#   * Note: itertools is a module -- we'll see "modules" in a moment
# * permutations
# * combinations
# * product (Cartesian -- like nested for loops)

# %%
from itertools import permutations
p = permutations(range(3))
print(*p)
# Out:
# (0, 1, 2) (0, 2, 1) (1, 0, 2) (1, 2, 0) (2, 0, 1) (2, 1, 0)

# %%
from itertools import combinations
c = combinations(range(4), 2)
print(*c)
# Out:
# (0, 1) (0, 2) (0, 3) (1, 2) (1, 3) (2, 3)

# %%
from itertools import product
p = product('ab', range(3))
print(*p)
# Out:
# ('a', 0) ('a', 1) ('a', 2) ('b', 0) ('b', 1) ('b', 2)

# %% [markdown]
# # List comprehensions
#
# Ref: [11-List-Comprehensions.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/11-List-Comprehensions.ipynb)
#
# Readable one-line iteration
#
# `[expr for var in iterable]`

# %%
# The verbose way
L = []
for n in range(12):
    L.append(n ** 2)
L

# %%
# The succinct way
[n ** 2 for n in range(12)]

# %%
# multiple iterators on one line
[(i, j) for i in range(2) for j in range(3)]

# %%
# conditionals on the iterator
[val for val in range(20) if val % 3 > 0]

# %%
# conditionals on the value
[val if val % 2 else -val for val in range(20) if val % 3 > 0]

# %% [markdown]
# ## set and dictionary comprehensions

# %%
# curly braces for set comprensions
{n**2 for n in range(12)}

# %%
# with a colon for dict comprehensions
{n:n**2 for n in range(6)}

# %%
# use parentheses to get a generator, i.e., a list iterator
(n**2 for n in range(6))

# %%
list((n**2 for n in range(6)))

# %% [markdown]
# # Generators
#
# Ref: [12-Generators.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/12-Generators.ipynb)
#
# If a list is a collection of values -- this consumes memory.
#
# A generator is a recipe for creating values -- the values are created when needed.
#
# Lists and generators both expose the same iterator interface.

# %%
# Generators can continue indefinitely.  For example...
# Q: What happens if you change the value of "n"
from itertools import count

n = 40
factors = [2, 3, 5, 7]
G = (i for i in count() if all(i % n > 0 for n in factors))
for val in G:
    print(val, end=' ')
    if val > n: break

# %%
# Unlike lists, generators are single-use for iteration
G = (n ** 2 for n in range(12))
print('first time:', list(G))
print('second time:', list(G))

# %%
# This might be useful if you want to stop and restart. For example, suppose
# you're processing a lot of files. You may want to pause every so often.
G = (n**2 for n in range(12))
for n in G:
    print(n, end=' ')
    if n > 30: break

print("\ndoing something in between")

for n in G:
    print(n, end=' ')

# %% [markdown]
# ## `yield`

# %%
# Just as there are two ways of constructing a list
L1 = [n ** 2 for n in range(12)]

L2 = []
for n in range(12):
    L2.append(n ** 2)

print(L1)
print(L2)

# %%
# There are two ways of constructing a generator
G1 = (n ** 2 for n in range(12))

def gen():
    for n in range(12):
        yield n ** 2

G2 = gen()
print(*G1)
print(*G2)

# %%
# VanderPlas has an interesting use of generators for generating prime numbers
def gen_primes(N):
    """Generate primes up to N"""
    primes = set()
    for n in range(2, N):
        if all(n % p > 0 for p in primes):
            primes.add(n)
            yield n

print(*gen_primes(100))

# %%
# By the way, check out the function documentation by typing the next line
# Pause after you type the left parens "("
#gen_primes(3)

# %% [markdown]
# ## remember, generators are single use
#
# But you can always recreate the generator to start from scratch

# %% [markdown]
# # Modules and packages
#
# `import` statement
#
# The import statement preserves a module's content in a namespace.
#
# You can then access the contents of the module using "dot" notation.
#
# Ref: [13-Modules-and-Packages.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/13-Modules-and-Packages.ipynb)

# %%
# you can import an entire module
import math
math.cos(math.pi)
# Out:
# -1.0

# %%
# you can also import with an alias
import numpy as np
np.cos(np.pi)

# %%
# and you can import only what you want
from math import cos, pi
cos(pi)

# %%
# you can import the entire namespace, but this is dangerous!
from math import *
sin(pi) ** 2 + cos(pi) ** 2

# %% [markdown]
# ## useful built-in modules
#
# * `os` and `sys`: Tools for interfacing with the operating system, including navigating file directory structures and executing shell commands
# * `math` and `cmath`: Mathematical functions and operations on real and complex numbers
# * `itertools`: Tools for constructing and interacting with iterators and generators
# * `functools`: Tools that assist with functional programming
# * `random`: Tools for generating pseudorandom numbers
# * `pickle`: Tools for object persistence: saving objects to and loading objects from disk
# * `json` and `csv`: Tools for reading JSON-formatted and CSV-formatted files.
# * `urllib`: Tools for doing HTTP and other web requests.
#
# Reference: [Python standard library](https://docs.python.org/3/library/) -- python.org

# %% [markdown]
# ## third-party modules
#
# Many of these will need to be "installed" before they can be "imported".
# The standard registry for importing modules
# is the *Python Package Index* (PyPI), using the `pip` command. We'll be using this later in the course.
#
# Reference: [PyPI](https://pypi.org/)

# %% [markdown]
# # Strings and regular expressions
#
# * define string with single or double quotes
# * use triple quotes for multi-line strings
# * Ref: [14-Strings-and-Regular-Expressions.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/14-Strings-and-Regular-Expressions.ipynb)

# %%
# define strings with single or double quotes
x = 'a string'
y = "a string"
x == y

# %%
a = """this
is
a 
mutli-line string"""
print(a)
a

# %% [markdown]
# ## string functions
#
# Capitalization
#
# * `upper`
# * `lower`
# * `capitalize`
# * `title`
# * `swapcase`
#
# Whitespace
#
# * `strip` -- strip characters, blank by default
# * `lstrip` -- strip just from the left
# * `rstrip`
# * `center` -- center string with prescribed length
# * `ljust`
# * `rjust`
# * `zfill` -- left-padding with zeroes
#
# Substrings
#
# * `find(string, substring)` -- index of substring, -1 if it's not there
# * `rfind` -- start from right
# * `index` -- like find, but throws error
# * `rindex`
# * `replace` -- replace all ocurrences
#
# Splitting
#
# * `partition`
# * `split`
# * `splitlines`
# * `join` -- undoes split with substring

# %%
line = 'the quick brown fox jumped over a lazy dog'
line.find('fox')

# %%
line.split()

# %%
# split and rejoin
"-".join(line.split())

# %% [markdown]
# ## format strings
#
# * [format specification mini language](https://docs.python.org/3/library/string.html#formatspec) -- python.org
#   * [format examples](https://docs.python.org/3/library/string.html#format-examples) -- good place to look for reminders

# %%
# string conversion
pi = 3.14159
str(pi)
# Out:
# '3.14159'

# %%
# string concatenation
"the value of pi is: " + str(pi)
# Out:
# 'the value of pi is: 3.14159'

# %%
# format strings allow more control
"The value of pi is {0}, and 2pi is {1}".format(pi, 2 * pi)
# Out:
# 'The value of pi is 3.14159, and 2pi is 6.28318'

# %%
# with explicit formatting
"pi = {0:.2f}".format(pi)
# Out:
# 'pi = 3.14'

# %% [markdown]
# ## regular expressions
#
# This mini-language offers remarkable power for string manipulation, but it can seem a bit obscure.
#
# * Reference: [Section 14 of VanderPlas](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/14-Strings-and-Regular-Expressions.ipynb)

# %% [markdown]
# # Other resources
#
# * [15-Preview-of-Data-Science-Tools.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/15-Preview-of-Data-Science-Tools.ipynb)
# * [16-Further-Resources.ipynb](https://github.com/jakevdp/WhirlwindTourOfPython/blob/master/16-Further-Resources.ipynb)
